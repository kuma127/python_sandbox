# %% [markdown]
# # 20230617 私と #pyhack

# %%
import pandas as pd

# %%
df = pd.read_csv('./20230617_pyhack.csv')

# %%
df
# Out:
#     index        date  times  is_camp  \
# 0       1  2018-04-07     87        0
# 1       2  2018-06-09     89        0
# 2       3  2018-09-29     92        0
# 3       4  2018-10-27     93        0
# 4       5  2018-12-22     94        0
# 5       6  2019-01-18     95        1
# 6       7  2019-02-16     96        0
# 7       8  2019-03-23     97        0
# 8       9  2019-05-25     99        0
# 9      10  2019-06-22    100        0
# 10     11  2019-07-12    101        1
# 11     12  2019-08-10    102        0
# 12     13  2019-09-07    103        0
# 13     14  2019-10-19    104        0
# 14     15  2019-11-30    105        0
# 15     16  2019-12-14    106        0
# 16     17  2020-01-17    107        1
# 17     18  2020-02-01    108        0
# 18     19  2020-03-07    109        0
# 19     20  2020-04-04    110        0
# 20     21  2020-05-09    111        0
# 21     22  2020-06-13    112        0
# 22     23  2020-07-23    113        1
# ...

# %%
import plotly.io as pio
pio.renderers.default = 'iframe' # or 'colab' or 'iframe' or 'iframe_connected' or 'sphinx_gallery'

# %%
import plotly.express as px
px.pie(df, values=df.value_counts().values, names="contents_type")
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_10.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
px.pie(df, values=df.value_counts().values, names="work_type")
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_11.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
